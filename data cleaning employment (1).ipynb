# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp

# %% [markdown]
# ## Importing Data

# %%
df= pd.read_csv(r"E:\PyCharm 2025.2.2\Salaries (1).csv")
print(df)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# ### Looking for Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Dropping Unnecessary columns

# %%
df= df.drop(columns= "Status")

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
#looking for unneccessary colimns, it has all null values so we will drop the column

# %%
df["Notes"]
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 148649   NaN
# 148650   NaN
# 148651   NaN
# 148652   NaN
# 148653   NaN
# Name: Notes, Length: 148654, dtype: float64

# %%
df=df.drop(columns= "Notes")

# %%
#now we have 11 columns as the column notes has been dropped
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# ### Properly capitalizing the names

# %%
df["EmployeeName"]= df["EmployeeName"].str.lower().str.title()

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     Nathaniel Ford
# 1            2       Gary Jimenez
# 2            3     Albert Pardini
# 3            4  Christopher Chong
# 4            5    Patrick Gardner
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not Provided
# 148651  148652       Not Provided
# 148652  148653       Not Provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
#the names were written in capital we made them correct by writing just the first letter capital

# %% [markdown]
# ### Converting values to NAN for dropping

# %%
df["BasePay"]= df["BasePay"].replace("Not Provided", np.nan)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     Nathaniel Ford
# 1            2       Gary Jimenez
# 2            3     Albert Pardini
# 3            4  Christopher Chong
# 4            5    Patrick Gardner
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not Provided
# 148651  148652       Not Provided
# 148652  148653       Not Provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6
# ...                                                ...        ...
# 148649                                       Custodian          0
# ...

# %%
df= df.dropna()

# %%
#by using drop na we dropped all rows having base pay = nan, now we also want to delete rows where basepay is zero

# %%
df
# Out:
#             Id        EmployeeName                      JobTitle    BasePay  \
# 36159    36160      Gary Altenberg  Lieutenant, Fire Suppression  128808.87
# 36160    36161        Gregory Suhr               Chief of Police   302578.0
# 36161    36162          Khoa Trinh   Electronic Maintenance Tech   111921.0
# 36162    36163  Joanne Hayes-White        Chief, Fire Department  296943.01
# 36163    36164   Frederick Binkley     EMT/Paramedic/Firefighter  126863.19
# ...        ...                 ...                           ...        ...
# 148645  148646    Carolyn A Wilson     Human Services Technician          0
# 148647  148648      Joann Anderson   Communications Dispatcher 2          0
# 148648  148649         Leon Walker                     Custodian          0
# 148649  148650       Roy I Tillery                     Custodian          0
# 148653  148654           Joe Lopez    Counselor, Log Cabin Ranch          0
#
# ...

# %%
df.loc[:,"BasePay"]= df["BasePay"].replace("0", np.nan)

# %%
df
# Out:
#             Id        EmployeeName                      JobTitle    BasePay  \
# 36159    36160      Gary Altenberg  Lieutenant, Fire Suppression  128808.87
# 36160    36161        Gregory Suhr               Chief of Police   302578.0
# 36161    36162          Khoa Trinh   Electronic Maintenance Tech   111921.0
# 36162    36163  Joanne Hayes-White        Chief, Fire Department  296943.01
# 36163    36164   Frederick Binkley     EMT/Paramedic/Firefighter  126863.19
# ...        ...                 ...                           ...        ...
# 148645  148646    Carolyn A Wilson     Human Services Technician        NaN
# 148647  148648      Joann Anderson   Communications Dispatcher 2        NaN
# 148648  148649         Leon Walker                     Custodian        NaN
# 148649  148650       Roy I Tillery                     Custodian        NaN
# 148653  148654           Joe Lopez    Counselor, Log Cabin Ranch        NaN
#
# ...

# %%
df= df.dropna()

# %%
df
# Out:
#             Id            EmployeeName                      JobTitle  \
# 36159    36160          Gary Altenberg  Lieutenant, Fire Suppression
# 36160    36161            Gregory Suhr               Chief of Police
# 36161    36162              Khoa Trinh   Electronic Maintenance Tech
# 36162    36163      Joanne Hayes-White        Chief, Fire Department
# 36163    36164       Frederick Binkley     EMT/Paramedic/Firefighter
# ...        ...                     ...                           ...
# 148613  148614         Nanette M Lloyd                 Special Nurse
# 148616  148617       Afakasi O Afakasi        Public Service Trainee
# 148617  148618  Charles F Williams Iii                Pool Lifeguard
# 148619  148620           Ian V Cameron  IS Program Analyst-Assistant
# 148620  148621         India C Sabater             Recreation Leader
#
#           BasePay OvertimePay  OtherPay  Benefits   TotalPay  \
# 36159   128808.87   220909.48  13126.31  44430.12  362844.66
# ...

# %%
df= df.replace("0", np.nan)

# %%
df
# Out:
#             Id            EmployeeName                      JobTitle  \
# 36159    36160          Gary Altenberg  Lieutenant, Fire Suppression
# 36160    36161            Gregory Suhr               Chief of Police
# 36161    36162              Khoa Trinh   Electronic Maintenance Tech
# 36162    36163      Joanne Hayes-White        Chief, Fire Department
# 36163    36164       Frederick Binkley     EMT/Paramedic/Firefighter
# ...        ...                     ...                           ...
# 148613  148614         Nanette M Lloyd                 Special Nurse
# 148616  148617       Afakasi O Afakasi        Public Service Trainee
# 148617  148618  Charles F Williams Iii                Pool Lifeguard
# 148619  148620           Ian V Cameron  IS Program Analyst-Assistant
# 148620  148621         India C Sabater             Recreation Leader
#
#           BasePay OvertimePay  OtherPay  Benefits   TotalPay  \
# 36159   128808.87   220909.48  13126.31  44430.12  362844.66
# ...

# %%
df= df.dropna()

# %%
df
# Out:
#             Id        EmployeeName                        JobTitle    BasePay  \
# 36159    36160      Gary Altenberg    Lieutenant, Fire Suppression  128808.87
# 36160    36161        Gregory Suhr                 Chief of Police   302578.0
# 36161    36162          Khoa Trinh     Electronic Maintenance Tech   111921.0
# 36162    36163  Joanne Hayes-White          Chief, Fire Department  296943.01
# 36163    36164   Frederick Binkley       EMT/Paramedic/Firefighter  126863.19
# ...        ...                 ...                             ...        ...
# 147467  147468      Monica Sanchez      Publ Svc Aide-Asst to Prof    1182.12
# 147535  147536      Marken Hampton                  Camp Assistant    1160.08
# 147658  147659   Raymond A Whitley  Custodial Assistant Supervisor    1282.97
# 147659  147660    Ruth A Armstrong              Nurse Practitioner     426.44
# 147689  147690     Patrisha A Kral                   Special Nurse     365.68
#
# ...

# %%
df
# Out:
#             Id        EmployeeName                        JobTitle    BasePay  \
# 36159    36160      Gary Altenberg    Lieutenant, Fire Suppression  128808.87
# 36160    36161        Gregory Suhr                 Chief of Police   302578.0
# 36161    36162          Khoa Trinh     Electronic Maintenance Tech   111921.0
# 36162    36163  Joanne Hayes-White          Chief, Fire Department  296943.01
# 36163    36164   Frederick Binkley       EMT/Paramedic/Firefighter  126863.19
# ...        ...                 ...                             ...        ...
# 147467  147468      Monica Sanchez      Publ Svc Aide-Asst to Prof    1182.12
# 147535  147536      Marken Hampton                  Camp Assistant    1160.08
# 147658  147659   Raymond A Whitley  Custodial Assistant Supervisor    1282.97
# 147659  147660    Ruth A Armstrong              Nurse Practitioner     426.44
# 147689  147690     Patrisha A Kral                   Special Nurse     365.68
#
# ...

# %%
# we have solved issue of all the null numbers and the rows which had no values

# %%
df.to_excel(r"E:\PyCharm 2025.2.2\cleaned_data.xlsx", index=False)

# %%
import os
print(os.path.exists(r"E:\PyCharm 2025.2.2\cleaned_data.xlsx"))
# Out:
# True
